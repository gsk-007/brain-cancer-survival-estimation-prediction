# %% [markdown]
# # Brain Cancer Survival Estimation Pediction
#
#
# [data link](https://wiki.cancerimagingarchive.net/pages/viewpage.action?pageId=70225642#70225642c94d520b7b5f42e7925602d723412459)

# %%
# Importing Libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# Importing Models
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.kernel_ridge import KernelRidge

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('./UPENN-GBM_clinical_info_v1.0.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          671 non-null    object
#  1   Gender                      671 non-null    object
#  2   Age_at_scan_years           671 non-null    float64
#  3   Survival_from_surgery_days  671 non-null    object
#  4   IDH1                        671 non-null    object
#  5   MGMT                        671 non-null    object
#  6   KPS                         671 non-null    object
#  7   GTR_over90percent           671 non-null    object
#  8   Time_since_baseline_preop   671 non-null    object
#  9   PsP_TP_score                60 non-null     float64
# dtypes: float64(2), object(8)
# memory usage: 52.5+ KB

# %%
# Dropping Redundant Columns
new_df = df.drop(['PsP_TP_score','GTR_over90percent','Time_since_baseline_preop','IDH1','MGMT','KPS'],axis=1)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          671 non-null    object
#  1   Gender                      671 non-null    object
#  2   Age_at_scan_years           671 non-null    float64
#  3   Survival_from_surgery_days  671 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 21.1+ KB

# %%
# Converting String to Integer Values 
new_df['Survival_from_surgery_days'] = new_df['Survival_from_surgery_days'].astype(int)

new_df['Age_at_scan_years'] = new_df['Age_at_scan_years'].round().astype(int)

new_df.reset_index()
# Out:
#      index                  ID Gender  Age_at_scan_years  \
# 0        1  UPENN-GBM-00002_11      F                 61
# 1        5  UPENN-GBM-00006_11      M                 53
# 2        7  UPENN-GBM-00008_11      F                 55
# 3        8  UPENN-GBM-00009_11      M                 69
# 4       10  UPENN-GBM-00011_11      F                 40
# ..     ...                 ...    ...                ...
# 447    641  UPENN-GBM-00601_11      M                 60
# 448    642  UPENN-GBM-00602_11      M                 77
# 449    644  UPENN-GBM-00604_11      F                 62
# 450    649  UPENN-GBM-00609_11      M                 29
# 451    651  UPENN-GBM-00611_11      M                 58
#
#      Survival_from_surgery_days
# 0                           291
# 1                           626
# 2                           469
# 3                           561
# 4                           798
# ..                          ...
# 447                         435
# 448                         252
# 449                         234
# 450                         138
# 451                         551
#
# [452 rows x 5 columns]

# %%
new_df.head()
# Out:
#                     ID Gender  Age_at_scan_years  Survival_from_surgery_days
# 1   UPENN-GBM-00002_11      F                 61                         291
# 5   UPENN-GBM-00006_11      M                 53                         626
# 7   UPENN-GBM-00008_11      F                 55                         469
# 8   UPENN-GBM-00009_11      M                 69                         561
# 10  UPENN-GBM-00011_11      F                 40                         798

# %%
new_df.describe()
# Out:
#        Age_at_scan_years  Survival_from_surgery_days
# count         452.000000                  452.000000
# mean           63.699115                  422.165929
# std            11.964200                  355.260164
# min            21.000000                    3.000000
# 25%            56.000000                  157.750000
# 50%            64.000000                  366.000000
# 75%            72.000000                  554.000000
# max            88.000000                 2207.000000

# %%
# Saving the csv File
# new_df.to_csv('clinical-modifed.csv',index=False)

# %% [markdown]
# ## Feature Extraction

# %%
clinical_data_df = pd.read_csv('./clinical-modifed.csv')
cd_df = clinical_data_df.copy()

# %%
import os

# %%
# os.listdir('./data/')
feature= pd.DataFrame()
csv_files = os.listdir('./data')

for file in csv_files:
    df_temp = pd.read_csv('./data/'+file)
    cd_df = pd.merge(cd_df,df_temp,left_on="ID",right_on="SubjectID",how="left",suffixes=('', '_drop'))

# %%
cd_df.drop([col for col in cd_df.columns if 'drop' in col], axis=1, inplace=True)

# %%
cd_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 cd_df.columns
#
# NameError: name 'cd_df' is not defined

# %%
#cd_df.to_csv('training-data.csv',index=False)

# %%
df = pd.read_csv('./training-data.csv', low_memory=False)

# %%
new_df = df.dropna()
new_df.describe()
# Out:
#        Age_at_scan_years  Survival_from_surgery_days  \
# count         118.000000                  118.000000
# mean           61.398305                  481.067797
# std            12.430415                  408.719236
# min            22.000000                   12.000000
# 25%            54.000000                  208.250000
# 50%            61.000000                  383.500000
# 75%            69.000000                  582.250000
# max            87.000000                 2207.000000
#
#        DSC_ap-rCBV_ED_Intensity_CoefficientOfVariation  \
# count                                       118.000000
# mean                                          0.839961
# std                                           0.204523
# min                                           0.383445
# 25%                                           0.682896
# 50%                                           0.855030
# 75%                                           0.990443
# max                                           1.603620
#
#        DSC_ap-rCBV_ED_Intensity_Energy  \
# count                     1.180000e+02
# mean                      6.531428e+07
# std                       5.158566e+07
# min                       5.305319e+06
# 25%                       2.648920e+07
# 50%                       5.096723e+07
# 75%                       8.405728e+07
# max                       2.924892e+08
#
#        DSC_ap-rCBV_ED_Intensity_InterQuartileRange  \
# count                                   118.000000
# mean                                     23.720339
# std                                      12.074474
# min                                       7.000000
# 25%                                      15.000000
# 50%                                      20.000000
# 75%                                      30.000000
# max                                      67.000000
#
#        DSC_ap-rCBV_ED_Intensity_Kurtosis  DSC_ap-rCBV_ED_Intensity_Maximum  \
# count                         118.000000                        118.000000
# mean                           11.717749                        228.601695
# std                             6.579110                         31.253346
# min                             2.973199                        108.000000
# 25%                             7.195066                        212.000000
# 50%                            10.057632                        237.000000
# 75%                            14.176321                        255.000000
# max                            38.669859                        255.000000
#
#        DSC_ap-rCBV_ED_Intensity_Mean  \
# count                     118.000000
# mean                       30.909500
# std                        14.516671
# min                        11.933020
# 25%                        20.842317
# 50%                        26.761068
# 75%                        39.607503
# max                        92.803610
#
#        DSC_ap-rCBV_ED_Intensity_MeanAbsoluteDeviation  \
# count                                    1.180000e+02
# mean                                     6.074547e-13
# std                                      3.536699e-12
# min                                     -9.771044e-12
# 25%                                     -6.271516e-13
# 50%                                      7.260399e-14
# 75%                                      1.170711e-12
# max                                      2.020821e-11
#
#        DSC_ap-rCBV_ED_Intensity_Median  ...  \
# count                       118.000000  ...
# mean                         23.881356  ...
# std                          13.943212  ...
# min                           0.000000  ...
# 25%                          14.000000  ...
# 50%                          19.000000  ...
# 75%                          32.000000  ...
# max                          86.000000  ...
#
#        T2_NC_GLSZM_Bins-16_Radius-1_ZoneSizeMean  \
# count                                 118.000000
# mean                                   17.478734
# std                                    10.999177
# min                                     1.758621
# 25%                                     8.217772
# 50%                                    16.218972
# 75%                                    23.557361
# max                                    45.943787
#
#        T2_NC_GLSZM_Bins-16_Radius-1_ZoneSizeNonUniformity  \
# count                                         118.000000
# mean                                          151.734460
# std                                           143.127550
# min                                             7.774194
# 25%                                            58.286422
# 50%                                           107.354817
# 75%                                           201.904979
# max                                           835.873753
#
#        T2_NC_GLSZM_Bins-16_Radius-1_ZoneSizeNoneUniformityNormalized  \
# count                                         118.000000
# mean                                            0.273270
# std                                             0.051019
# min                                             0.151855
# 25%                                             0.235387
# 50%                                             0.269263
# 75%                                             0.308480
# max                                             0.423002
#
#        T2_NC_GLSZM_Bins-16_Radius-1_ZoneSizeVariance  T2_NC_NGTDM_Busyness  \
# count                                     118.000000            118.000000
# mean                                    27808.439843             84.036280
# std                                     56382.587789            104.802790
# min                                         0.941736              0.645038
# 25%                                      1370.045817             18.536621
# 50%                                      6307.069041             55.669503
# 75%                                     31363.118182            114.290911
# max                                    466521.423800            678.392010
#
#        T2_NC_NGTDM_Coarsness  T2_NC_NGTDM_Complexity  T2_NC_NGTDM_Contrast  \
# count             118.000000              118.000000            118.000000
# mean                0.000822             1029.692432              0.621053
# std                 0.002437              324.244530              0.376285
# min                 0.000010              577.798506              0.096414
# 25%                 0.000053              847.356917              0.355515
# 50%                 0.000134              952.259949              0.515595
# 75%                 0.000392             1111.327771              0.769964
# max                 0.016765             2327.248433              2.046871
#
#        T2_NC_NGTDM_Strength  T2_NC_LBP_Radius-1_Bins-16_LBP
# count            118.000000                      118.000000
# mean               0.088802                   102727.858049
# std                0.237433                   126829.309293
# min                0.001178                      653.769380
# 25%                0.007150                    25132.769310
# 50%                0.016018                    63629.804780
# 75%                0.049986                   133162.887425
# max                1.826919                   833166.306200
#
# [8 rows x 4754 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
new_df['Gender'].value_counts()
# Out:
# M    71
# F    47
# Name: Gender, dtype: int64

# %%
new_df['Gender'] = le.fit_transform(new_df['Gender'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1664\934390276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Gender'] = le.fit_transform(new_df['Gender'])

# %%
df1 = new_df['Survival_from_surgery_days'][new_df['Gender']==1]
# Out:
# 1      626
# 7      272
# 8      509
# 11     425
# 15    1504
# Name: Survival_from_surgery_days, dtype: int64

# %%
# Create another figure
plt.figure(figsize=(10,6))

# Start with positve examples
plt.scatter( new_df['Age_at_scan_years'][new_df['Gender']==1],
            new_df['Survival_from_surgery_days'][new_df['Gender']==1], 
            
            c="salmon") # define it as a scatter figure

# Now for negative examples, we want them on the same plot, so we call plt again
plt.scatter(new_df['Age_at_scan_years'][new_df['Gender']==0],
    new_df['Survival_from_surgery_days'][new_df['Gender']==0],
            c="lightblue") # axis always come as (x, y)

# Add some helpful info
plt.title("M Vs F")
plt.ylabel("Survival")
plt.legend(["Male", "No Female"])
plt.xlabel("Age");

# %%
corrM = new_df.corr()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1664\365703186.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrM = new_df.corr()

# %%
corrM['Survival_from_surgery_days'][lambda x: abs(x)>0.323]
feature_columns = corrM['Survival_from_surgery_days'][lambda x: abs(x)>0.323].keys()
# len(corrM['Survival_from_surgery_days'][lambda x: abs(x)>0.323])

# %%
filtered_df = new_df[feature_columns]

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 0 to 329
# Data columns (total 51 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Age_at_scan_years                                                   118 non-null    int64
#  1   Survival_from_surgery_days                                          118 non-null    int64
#  2   DSC_ap-rCBV_ED_Histogram_Bins-16_Bins-16_Bin-11_Probability         118 non-null    float64
#  3   DSC_PH_ED_Histogram_Bins-16_Bins-16_Bin-13_Frequency                118 non-null    float64
#  4   DSC_PH_ED_Histogram_Bins-16_Bins-16_Bin-14_Frequency                118 non-null    float64
#  5   DSC_PH_ED_Histogram_Bins-16_Bins-16_Bin-15_Frequency                118 non-null    float64
#  6   DTI_AD_ET_Intensity_InterQuartileRange                              118 non-null    float64
#  7   DTI_AD_NC_Histogram_Bins-16_Bins-16_Bin-10_Probability              118 non-null    float64
#  8   DTI_AD_NC_Histogram_Bins-16_Bins-16_Bin-11_Probability              118 non-null    float64
#  9   DTI_AD_NC_Histogram_Bins-16_Bins-16_Bin-12_Probability              118 non-null    float64
#  10  DTI_AD_NC_Histogram_Bins-16_Bins-16_Bin-14_Probability              118 non-null    float64
#  11  DTI_AD_NC_Histogram_Bins-16_Bins-16_Mean                            118 non-null    float64
#  12  DTI_AD_NC_Histogram_Bins-16_Bins-16_Median                          118 non-null    float64
#  13  DTI_AD_NC_Histogram_Bins-16_Bins-16_NinetiethPercentile             118 non-null    float64
#  14  DTI_AD_NC_Histogram_Bins-16_Bins-16_RootMeanSquare                  118 non-null    float64
#  15  DTI_AD_NC_Histogram_Bins-16_Bins-16_SeventyFifthPercentile          118 non-null    float64
#  16  DTI_AD_NC_GLCM_Bins-16_Radius-1_AutoCorrelation                     118 non-null    float64
#  17  DTI_AD_NC_GLRLM_Bins-16_Radius-1_HighGreyLevelRunEmphasis           118 non-null    float64
#  18  DTI_AD_NC_GLRLM_Bins-16_Radius-1_LongRunHighGreyLevelEmphasis       118 non-null    float64
#  19  DTI_AD_NC_GLRLM_Bins-16_Radius-1_ShortRunHighGreyLevelEmphasis      118 non-null    float64
#  20  DTI_AD_NC_NGTDM_Complexity                                          118 non-null    float64
#  21  DTI_RD_NC_Histogram_Bins-16_Bins-16_Bin-12_Probability              118 non-null    float64
#  22  DTI_RD_NC_Histogram_Bins-16_Bins-16_SeventyFifthPercentile          118 non-null    float64
#  23  DTI_RD_NC_GLRLM_Bins-16_Radius-1_LongRunHighGreyLevelEmphasis       118 non-null    float64
#  24  DTI_TR_ET_Intensity_InterQuartileRange                              118 non-null    float64
#  25  DTI_TR_NC_Histogram_Bins-16_Bins-16_Bin-11_Probability              118 non-null    float64
#  26  DTI_TR_NC_Histogram_Bins-16_Bins-16_Bin-12_Probability              118 non-null    float64
#  27  DTI_TR_NC_Histogram_Bins-16_Bins-16_Bin-5_Probability               118 non-null    float64
#  28  DTI_TR_NC_Histogram_Bins-16_Bins-16_RootMeanSquare                  118 non-null    float64
#  29  DTI_TR_NC_Histogram_Bins-16_Bins-16_SeventyFifthPercentile          118 non-null    float64
#  30  DTI_TR_NC_GLRLM_Bins-16_Radius-1_HighGreyLevelRunEmphasis           118 non-null    float64
#  31  DTI_TR_NC_GLRLM_Bins-16_Radius-1_LongRunHighGreyLevelEmphasis       118 non-null    float64
#  32  FLAIR_NC_Intensity_InterQuartileRange                               118 non-null    float64
#  33  FLAIR_NC_Intensity_Variance                                         118 non-null    float64
#  34  FLAIR_NC_Histogram_Bins-16_Bins-16_Bin-15_Probability               118 non-null    float64
#  35  FLAIR_NC_Histogram_Bins-16_Bins-16_InterQuartileRange               118 non-null    float64
#  36  FLAIR_NC_Histogram_Bins-16_Bins-16_RobustMeanAbsoluteDeviation1090  118 non-null    float64
#  37  FLAIR_NC_Histogram_Bins-16_Bins-16_StandardDeviation                118 non-null    float64
#  38  FLAIR_NC_Histogram_Bins-16_Bins-16_Variance                         118 non-null    float64
#  39  FLAIR_NC_GLCM_Bins-16_Radius-1_ClusterProminence                    118 non-null    float64
#  40  FLAIR_NC_GLRLM_Bins-16_Radius-1_LongRunEmphasis                     118 non-null    float64
#  41  FLAIR_NC_GLRLM_Bins-16_Radius-1_LongRunHighGreyLevelEmphasis        118 non-null    float64
#  42  FLAIR_NC_GLRLM_Bins-16_Radius-1_ShortRunEmphasis                    118 non-null    float64
#  43  FLAIR_NC_GLSZM_Bins-16_Radius-1_GreyLevelVariance                   118 non-null    float64
#  44  FLAIR_NC_NGTDM_Contrast                                             118 non-null    float64
#  45  T1GD_ET_Intensity_Maximum                                           118 non-null    float64
#  46  T1_ET_GLRLM_Bins-16_Radius-1_ShortRunEmphasis                       118 non-null    float64
#  47  T1_NC_GLRLM_Bins-16_Radius-1_LongRunEmphasis                        118 non-null    float64
#  48  T1_NC_GLRLM_Bins-16_Radius-1_ShortRunEmphasis                       118 non-null    float64
#  49  T2_NC_GLRLM_Bins-16_Radius-1_LongRunEmphasis                        118 non-null    float64
#  50  T2_NC_GLRLM_Bins-16_Radius-1_ShortRunEmphasis                       118 non-null    float64
# dtypes: float64(49), int64(2)
# memory usage: 47.9 KB

# %%
#filtered_df.to_csv('train.csv',index=False)

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Age_at_scan_years  Survival_from_surgery_days  \
# 0                 61                         291
# 1                 53                         626
# 2                 55                         469
# 3                 40                         798
# 4                 68                         272
#
#    DSC_ap-rCBV_ED_Histogram_Bins-16_Bins-16_Bin-11_Probability  \
# 0                                           0.001406
# 1                                           0.001074
# 2                                           0.000848
# 3                                           0.000130
# 4                                           0.000191
#
#    DSC_PH_ED_Histogram_Bins-16_Bins-16_Bin-13_Frequency  \
# 0                                               71.0
# 1                                               72.0
# 2                                              111.0
# 3                                               20.0
# 4                                               36.0
#
#    DSC_PH_ED_Histogram_Bins-16_Bins-16_Bin-14_Frequency  \
# 0                                               22.0
# 1                                               48.0
# 2                                               32.0
# 3                                                5.0
# 4                                               24.0
#
#    DSC_PH_ED_Histogram_Bins-16_Bins-16_Bin-15_Frequency  \
# 0                                               10.0
# 1                                              104.0
# 2                                               11.0
# 3                                                5.0
# 4                                               23.0
#
#    DTI_AD_ET_Intensity_InterQuartileRange  \
# 0                                    28.0
# 1                                    16.0
# 2                                    10.0
# 3                                    50.0
# 4                                    33.0
#
#    DTI_AD_NC_Histogram_Bins-16_Bins-16_Bin-10_Probability  \
# 0                                           0.052519
# 1                                           0.095170
# 2                                           0.040616
# 3                                           0.057394
# 4                                           0.030381
#
#    DTI_AD_NC_Histogram_Bins-16_Bins-16_Bin-11_Probability  \
# 0                                           0.087401
# 1                                           0.089889
# 2                                           0.044818
# 3                                           0.050009
# 4                                           0.023686
#
#    DTI_AD_NC_Histogram_Bins-16_Bins-16_Bin-12_Probability  ...  \
# 0                                           0.127424       ...
# 1                                           0.074486       ...
# 2                                           0.014006       ...
# 3                                           0.038418       ...
# 4                                           0.023737       ...
#
#    FLAIR_NC_GLRLM_Bins-16_Radius-1_LongRunHighGreyLevelEmphasis  \
# 0                                          96.940634
# 1                                          47.620488
# 2                                          76.952450
# 3                                          84.438277
# 4                                          96.316006
#
#    FLAIR_NC_GLRLM_Bins-16_Radius-1_ShortRunEmphasis  \
# 0                                          0.980079
# 1                                          0.937439
# 2                                          0.974797
# 3                                          0.974369
# 4                                          0.983609
#
#    FLAIR_NC_GLSZM_Bins-16_Radius-1_GreyLevelVariance  FLAIR_NC_NGTDM_Contrast  \
# 0                                           7.858215                 0.498793
# 1                                           8.340937                 0.174021
# 2                                          10.008810                 0.479608
# 3                                           8.477602                 0.326496
# 4                                           8.264020                 0.340052
#
#    T1GD_ET_Intensity_Maximum  T1_ET_GLRLM_Bins-16_Radius-1_ShortRunEmphasis  \
# 0                      202.0                                       0.992906
# 1                      181.0                                       0.992546
# 2                      159.0                                       0.976954
# 3                      240.0                                       0.980654
# 4                      250.0                                       0.995410
#
#    T1_NC_GLRLM_Bins-16_Radius-1_LongRunEmphasis  \
# 0                                      1.030277
# 1                                      1.101141
# 2                                      1.132020
# 3                                      1.151729
# 4                                      1.020192
#
#    T1_NC_GLRLM_Bins-16_Radius-1_ShortRunEmphasis  \
# 0                                       0.992650
# 1                                       0.977954
# 2                                       0.974984
# 3                                       0.967070
# 4                                       0.995060
#
#    T2_NC_GLRLM_Bins-16_Radius-1_LongRunEmphasis  \
# 0                                      1.068664
# 1                                      1.368182
# 2                                      1.182262
# 3                                      1.243643
# 4                                      1.116171
#
#    T2_NC_GLRLM_Bins-16_Radius-1_ShortRunEmphasis
# 0                                       0.983939
# 1                                       0.928176
# 2                                       0.963164
# 3                                       0.951689
# 4                                       0.974976
#
# [5 rows x 51 columns]

# %%
y = df['Survival_from_surgery_days']
X = df.drop("Survival_from_surgery_days",axis=1)

# %%
X = scaler.fit_transform(X)

# %%
X.shape, y.shape
# Out:
# ((118, 50), (118,))

# %%
X_t, X_test, y_t, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
X_t.shape, y_t.shape,X_test.shape,y_test.shape
# Out:
# ((100, 50), (100,), (18, 50), (18,))

# %%
X_train, X_val, y_train, y_val = train_test_split(X_t, y_t, test_size=0.15, random_state=42)
X_train.shape, y_train.shape,X_val.shape,y_val.shape
# Out:
# ((85, 50), (85,), (15, 50), (15,))

# %%
# Create evaluation function (the competition uses RMSLE)
from sklearn.metrics import mean_squared_log_error, mean_absolute_error, r2_score

def rmsle(y_test, y_preds):
    """
    Caculates root mean squared log error between predictions and
    true labels.
    """
    return np.sqrt(mean_squared_log_error(y_test, y_preds))

# Create function to evaluate model on a few different levels
def show_scores(model):
    train_preds = model.predict(X_train)
    val_preds = model.predict(X_val)
    scores = {"Training MAE": mean_absolute_error(y_train, train_preds),
              "Valid MAE": mean_absolute_error(y_val, val_preds),
              "Training R^2": r2_score(y_train, train_preds),
              "Valid R^2": r2_score(y_val, val_preds)}
    return scores

# %%
# from sklearn.linear_model import LinearRegression
# from sklearn.linear_model import BayesianRidge
# from sklearn.linear_model import Lasso
# from sklearn.svm import SVR
# from sklearn.kernel_ridge import KernelRidge

# from sklearn.ensemble import GradientBoostingRegressor
# from sklearn.ensemble import RandomForestRegressor
# Put models in a dictionary
models = {"LinearRegression": LinearRegression(),
          "BayesianRidge": BayesianRidge(), 
          "Lasso": Lasso(), 
          "SVR-linear": SVR(kernel="linear"),
          "SVR-rbf": SVR(kernel="rbf"),
          "KernelRidge": KernelRidge(), 
          "GradientBoostingRegressor": GradientBoostingRegressor(), 
          "Random Forest": RandomForestRegressor()}

# Create function to fit and score models
def fit_and_score(models, X_train, X_test, y_train, y_test):
    """
    Fits and evaluates given machine learning models.
    models : a dict of different Scikit-Learn machine learning models
    X_train : training data
    X_test : testing data
    y_train : labels assosciated with training data
    y_test : labels assosciated with test data
    """
    # Random seed for reproducible results
    np.random.seed(42)
    # Make a list to keep model scores
    model_scores = {}
    # Loop through models
    for name, model in models.items():
        # Fit the model to the data
        model.fit(X_train, y_train)
        # Evaluate the model and append its score to model_scores
        model_scores[name] = show_scores(model)
    return model_scores

# %%
model_scores = fit_and_score(models=models,
                             X_train=X_train,
                             X_test=X_val,
                             y_train=y_train,
                             y_test=y_val)

model_scores
# Out:
# {'LinearRegression': {'Training MAE': 135.1836938594719,
#   'Valid MAE': 446.81764315967996,
#   'Training R^2': 0.7729198917570713,
#   'Valid R^2': -0.7561096248992145},
#  'BayesianRidge': {'Training MAE': 180.31500112786276,
#   'Valid MAE': 284.6088648424975,
#   'Training R^2': 0.6094515491872732,
#   'Valid R^2': 0.06527503412601743},
#  'Lasso': {'Training MAE': 173.61893089690213,
#   'Valid MAE': 297.25302220894537,
#   'Training R^2': 0.6591267378960413,
#   'Valid R^2': 0.00941389062079867},
#  'SVR-linear': {'Training MAE': 243.11184518309233,
#   'Valid MAE': 308.9378147338396,
#   'Training R^2': 0.019758479777977844,
#   'Valid R^2': -0.19759869346541659},
#  'SVR-rbf': {'Training MAE': 251.0892472681856,
#   'Valid MAE': 312.97722547262595,
#   'Training R^2': -0.024558484888111298,
#   'Valid R^2': -0.2338328262832159},
#  'KernelRidge': {'Training MAE': 180.0783635088705,
#   'Valid MAE': 290.51126977540684,
#   'Training R^2': 0.6175540260480579,
#   'Valid R^2': 0.028313986944274006},
#  'GradientBoostingRegressor': {'Training MAE': 9.838180238526684,
#   'Valid MAE': 384.0769995033945,
#   'Training R^2': 0.9989451644007847,
#   'Valid R^2': -0.5128677452198196},
#  'Random Forest': {'Training MAE': 92.26223529411766,
#   'Valid MAE': 293.44599999999997,
#   'Training R^2': 0.8897790787418164,
#   'Valid R^2': -0.003037376317600149}}

# %% [markdown]
# ## Hyperparameter Tuning
# We select the Random Forest Algorithm
